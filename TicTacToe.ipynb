# %%
board = {
    
        1: '' , 2: '' , 3: '',
        4: '' , 5: '' , 6: '',
        7: '' , 8: '' , 9: '',
}

# %%
def printboard():
    print(board[1]+'_|_'+board[2]+'_|_'+board[3])   
    print(board[4]+'_|_'+board[5]+'_|_'+board[6])
    print(board[7]+'_|_'+board[8]+'_|_'+board[9])

# %%
def wins():
    
    if board[1]==board[2]==board[3]!= '':
       
        cv=1
        return True
    elif board[4]==board[5]==board[6]!= '':
      
        cv=1
        return True
    elif board[7]==board[8]==board[9]!= '':
 
        cv=1
        return True
    elif board[1]==board[4]==board[7]!= '':

        cv=1
        return True
    elif board[2]==board[5]==board[8]!= '':
        cv=1
        return True
    elif board[3]==board[6]==board[9]!= '':
        cv=1
        return True
    elif board[1]==board[5]==board[9]!= '':
        cv=1
        return True
    elif board[7]==board[5]==board[3]!= '':
        cv=1
        return True
    else:
        return False

# %%
def manual():
 print('choosing................')
 print('chosse X or O')
 print('player 1')
 p1=input()
 print('player 2')
 p2=input()
 cv=0 #this variable is used to keep a track of win and draw
 print('which player wants to go first')      
 x=input()

 if(x.lower()=='player1' or x.lower()=='player2'):
        print(x+' '+'is the 1st one to go')
 else:
        while(x.lower()!='player1' or x.lower()!='player2'):
            print('enter again a valid one')
            x=input()
            if(x.lower()=='player1' or x.lower()=='player2'):
                print(x+' '+'is the 1st one to go')
                break
 if(x.lower()=='player1'):
    p=1
 else:
    p=2
    
 for i in range(1,6):   
    if(p==1):
        
         print('player 1 chance')
         play1=int(input())
         while(play1>=10 or play1<=0):
           print('enter again a valid input between 1 to 10')
           play1=int(input())
           if(play1<10 and play1>0):
             break
         if(board[play1]==''):
            board[play1]=p1
         else:
          while(board[play1]!=''):
            print('already filled enter new place')
            play1=int(input())
            if(board[play1]==''):
                    board[play1]=p1
                    break
         if(wins()):
            print('player1 won !!!!!!')
            cv=1
            break
         if(i!=5):
             printboard()
             print('player 2 chance')
             play2=int(input())
             while(play2>=10 or play2<=0):
               print('enter again a valid input between 1 to 10')
               play2=int(input())
               if(play2<10 and play2>0):
                 break
            
             if(board[play2]==''):
                board[play2]=p2
             else:
               while(board[play2]!=''):
                 print('already filled enter new place')
                 play2=int(input())
                 if(board[play2]==''):
                    board[play2]=p2
                    break
         if(wins()):
            print('player2 won !!!!!!')
            cv=1
            break
    else:
        print('player 2 chance')
        play2=int(input())
        while(play2>=10 or play2<=0):
           print('enter again a valid input between 1 to 10')
           play2=int(input())
           if(play2<10 and play2>0):
             break
        
        if(board[play2]==''):
            board[play2]=p2
        else:
          while(board[play2]!=''):
            print('already filled enter new place')
            play2=int(input())
            if(board[play2]==''):
                    board[play2]=p2
                    break
        if(wins()):
            print('player2 won !!!!!!')
            cv=1
            break
        
        if(i!=5):
            printboard()
            print('player 1 chance')
            play1=int(input())
            while(play1>=10 or play1<=0):
               print('enter again a valid input between 1 to 10')
               play1=int(input())
               if(play1<10 and play1>0):
                 break
           
            if(board[play1]==''):
             board[play1]=p1
            else:
              while(board[play1]!=''):
                print('already filled enter new place')
                play1=int(input())
                if(board[play1]==''):
                    board[play1]=p1
                    break
            if(wins()):
                print('player1 won !!!!!!')
                cv=1
                break
    printboard()
    print('want to continue? if yes type anything or if no type n')
    z=input()
    if(z.lower()=='n'):
      print('which player want to discontinue')
      z1=input()
      if(z1.lower()=='player1'):
        print('player2 wins!!!!')
        cv=1
        break
      else:
        print('player1 wins!!!!')
        cv=1
        break
        
   
 if(cv==0):
    print('-----------------------------')
    print('oh its a  draw !!')
 printboard()

# %%
# manual()

# %%
import random
def auto():
 print('choosing................')
 print('chosse X or O')
 print('player 1')
 p1=input()
 print('player 2')
 p2=input()
 cv=0 #this variable is used to keep a track of win and draw
 print('which player wants to go first')      
 x=input()

 if(x.lower()=='player1' or x.lower()=='player2'):
        print(x+' '+'is the 1st one to go')
 else:
        while(x.lower()!='player1' or x.lower()!='player2'):
            print('enter again a valid one')
            x=input()
            if(x.lower()=='player1' or x.lower()=='player2'):
                print(x+' '+'is the 1st one to go')
                break
 if(x.lower()=='player1'):
    p=1
 else:
    p=2
    
 for i in range(1,6):   
    if(p==1):
         #player1
         print('player 1 chance')
         
         pl1=input()
         if(pl1.lower()=='mark'):
            play1=random.randint(1,9)
         else:   
             while(pl1.lower()!='mark'):
               print('enter again a valid input i.e mark/MARK')
               pl1=input()
               if(pl1.lower()=='mark'):
                 play1=random.randint(1,9)
                 break
         if(board[play1]==''):
            board[play1]=p1
         else:
          while(board[play1]!=''):
            print('already filled type mark again')
            x1=input()
            play1=random.randint(1,9)
            if(board[play1]==''):
                    board[play1]=p1
                    break
         if(wins()):
            print('player1 won !!!!!!')
            cv=1
            break
         #player2
         if(i!=5):
            printboard()
            print('player 2 chance')
            pl2=input()
            if(pl2.lower()=='mark'):
                play2=random.randint(1,9)
            else:   
                 while(pl2.lower()!='mark'):
                   print('enter again a valid input i.e mark/MARK')
                   pl2=input()
                   if(pl2.lower()=='mark'):
                     play2=random.randint(1,9) 
                     break
          
            if(board[play2]==''):
                board[play2]=p2
            else:
              while(board[play2]!=''):
                print('already filled type mark again')
                x1=input()
                play2=random.randint(1,9) 
                if(board[play2]==''):
                    board[play2]=p2
                    break
            if(wins()):
                print('player2 won !!!!!!')
                cv=1
                break
        
    else:
        print('player 2 chance')
        pl2=input()
        if(pl2.lower()=='mark'):
            play2=random.randint(1,9)
        else:   
             while(pl2.lower()!='mark'):
               print('enter again a valid input i.e mark/MARK')
               pl2=input()
               if(pl2.lower()=='mark'):
                 play2=random.randint(1,9) 
                 break
        if(board[play2]==''):
            board[play2]=p2
        else:
          while(board[play2]!=''):
            print('already filled type mark again')
            x1=input()
            play2=random.randint(1,9) 
            if(board[play2]==''):
                    board[play2]=p2
                    break
        if(wins()):
            print('player2 won !!!!!!')
            cv=1
            break
        
        if(i!=5):
            printboard()
            print('player 1 chance')
            pl1=input()
            if(pl1.lower()=='mark'):
                play1=random.randint(1,9)
            else:   
                 while(pl1.lower()!='mark'):
                   print('enter again a valid input i.e mark/MARK')
                   pl1=input()
                   if(pl1.lower()=='mark'):
                     play1=random.randint(1,9)
                     break
            if(board[play1]==''):
                board[play1]=p1
            else:
                  while(board[play1]!=''):
                    print('already filled type mark again')
                    x1=input()
                    play1=random.randint(1,9)
                    if(board[play1]==''):
                        board[play1]=p1
                        break
            if(wins()):
                print('player1 won !!!!!!')
                cv=1
                break
            
    printboard()
    print('want to continue? if yes type anything or if no type n')
    z=input()
    if(z.lower()=='n'):
      print('which player want to discontinue')
      z1=input()
      if(z1.lower()=='player1'):
        print('player2 wins!!!!')
        cv=1
        break
      else:
        print('player1 wins!!!!')
        cv=1
        break
        
 print(cv)   
 if(cv==0):
    print('-----------------------------')
    print('oh its a  draw !!')
 printboard()

# %%
# auto()

# %%
def main():
    print('------------------------------')
    print('!!!!welcome to tic tac toe!!!')
    print('board is designed such that starts from 1 ends at 9')
    print(' 1  2  3')
    print(' 4  5  6')
    print(' 7  8  9')
    print('in MANUAL mode player will have to type numbers between 1 to 9 to fill the places')
    print('in auto mode type MARK each time and the computer will genearte x or o in board')
    print('NOTE:IF YOU TYPE A PLACE OR GET A PLACE WHICH IS ALREADY FILLED THEN YOU HAVE TO TYPE AGAIN')
    print('you can quit after each time both of player have given input')
    print('enter the mode in which you want to play options--MANUAL OR AUTO')
    man=input()
    if(man.lower()=='manual' or man.lower()=='auto'):
        if(man.lower()=='manual'):
            manual()
            
        else:
            auto()
            
    else:
        while(man.lower()!='manual' and man.lower()!='auto'):
            print('enter a valid input from auto or manual')
            man=input()
            if(man.lower()=='manual'):
                manual()
                
                break
            else:
                if(man.lower()=='auto'):   
                    auto()
                   
                    break

# %%
#this is used to call the main function which contains the game
no=1 
while(no==1):
 main()
 for key in board:#this is used to clear the board if u want to play again run this 
    board[key] = ''
 print('do you want to continue? if yes press anything if no press n')
 inp=input()
 if(inp=='n'):
   break
# Out:
# ------------------------------
# !!!!welcome to tic tac toe!!!
# board is designed such that starts from 1 ends at 9
#  1  2  3
#  4  5  6
#  7  8  9
# in MANUAL mode player will have to type numbers between 1 to 9 to fill the places
# in auto mode type MARK each time and the computer will genearte x or o in board
# NOTE:IF YOU TYPE A PLACE OR GET A PLACE WHICH IS ALREADY FILLED THEN YOU HAVE TO TYPE AGAIN
# you can quit after each time both of player have given input
# enter the mode in which you want to play options--MANUAL OR AUTO
# manual
# choosing................
# chosse X or O
# player 1
# x
# player 2
# o
# which player wants to go first
# player2
# player2 is the 1st one to go
# player 2 chance
# 7
# _|__|_
# _|__|_
# o_|__|_
# player 1 chance
# 1
# x_|__|_
# _|__|_
# o_|__|_
# want to continue? if yes type anything or if no type n
# y
# player 2 chance
# 9
# x_|__|_
# _|__|_
# o_|__|_o
# player 1 chance
# 3
# x_|__|_x
# _|__|_
# o_|__|_o
# ...
